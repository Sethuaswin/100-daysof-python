# %% [markdown]
# # <center>Band Name Generator Program </center>
#
# ## Overview
# * It will ask you the city you are belongs to
# * It will ask your pet's name
# * By end it will suggest Band's Name
#
# > In the process you will learn
# > * Printing
# > * Inputting
# > * Commenting
# > * Debugging
# > * Name Error
# > * Sntax Errors
# > * String Manipulation
# > * variables

# %% [markdown]
# ---
#
#
# ### 1. Printing Start

# %% [markdown]
# > print is a function followed by peranthesis `()`, it will print whatever called inside the function

# %%
# printing "Hello World" string

print("Hello World")
# Out:
# Hello World

# %%
# syntax error: unterminated string
print("Hello World!)
# Out:
#   File "<ipython-input-4-098ed1ec433a>", line 2
#     print("Hello World!)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# ### Coding Exercise
#
# **Instructions**<br>
# Write a program in main.py that prints some notes on Python programming into the Output console.<br>
#
# **Warning:** The output in your program should match the example output shown below exactly, character for character, even spaces and symbols should be identical, otherwise the tests won't pass.<br>
#
# **Example Output** <br>
# After you have written your code, you should run your program and it should print the following:
#
# ```
# Day 1 - Python Print Function
# The function is declared like this:
# print('what to print')
# ```

# %%
# Solution 1:
print("Day 1 - Python Print Function")
print("The function is declared like this:")
print("print('what to print')")
# Out:
# Day 1 - Python Print Function
# The function is declared like this:
# print('what to print')

# %%
# solution 2:
print("Day 1 - Python Print Function\nThe function is declared like this:\nprint('what to print')")
# Out:
# Day 1 - Python Print Function
# The function is declared like this:
# print('what to print')

# %% [markdown]
# printing seperate line in a single `print()` function using `\n`

# %% [markdown]
# ---
#
# ### 2. String Manipulation

# %% [markdown]
# #### 1. Seperate line in single `print()` function
#
# using `\n`

# %%
# example - Printing multiple lines in a single print function using \n
print("Hello World\nHello World\nHello World")
# Out:
# Hello World
# Hello World
# Hello World

# %% [markdown]
# #### 2. String concatination

# %% [markdown]
# Combine multiple string in single string using `+`

# %%
# Example - concat +
print("Hello" + "Aswin")
# Out:
# HelloAswin

# %% [markdown]
# As you can observed there is no space between the strings to add this there are two ways
#
# > * Add a space inside the quotes `print("Hello " + " Aswin")`
# > * Add a seperate concate as space between the strings `print("Hello" + " " + "Aswin")`

# %%
# Adding space inside the quotes
print("Hello " + "Aswin")
# Out:
# Hello Aswin

# %%
# Adding the seprate concat
print("Hello" + " " + "Aswin")
# Out:
# Hello Aswin

# %%
# Indentation Error
 print('Hello' + " " + "Aswin")
# Out:
#   File "<ipython-input-11-839b0485b202>", line 2
#     print('Hello' + " " + "Aswin")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### Coding Exercise
#
# **Instructions** <br>
# Look at the code in the code editor on the left. There are errors in all of the lines of code. Fix the code so that it runs without errors. <br>
#
# **Warning:** The output in your program should match the example output shown below exactly, character for character, even spaces and symbols should be identical, otherwise the tests won't pass. <br>
#
# **Example Output**<br>
# When you run your program, it should print the following:<br>
#
# ```
# Day 1 - String Manipulation
# String Concatenation is done with the "+" sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash
# ```
#
# ```python
# # Fix the code below 👇
#
# print(Day 1 - String Manipulation")
# print("String Concatenation is done with the "+" sign.")
#   print('e.g. print("Hello " + "world")')
# print(("New lines can be created with a backslash and n.")
# ```

# %%
# Solution
print("Day 1 - String Manipulation")
print('String Concatenation is done with the "+" sign.')
print('e.g. print("Hello " + "world")')
print("New lines can be created with a backslash and n.")
# Out:
# Day 1 - String Manipulation
# String Concatenation is done with the "+" sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash and n.

# %% [markdown]
# ---
# ### 3. Input Function

# %% [markdown]
# `input()` function will allow the user to input something
#
# synatx:<br>
# ```python
# input("A prompt for the user")
# ```

# %%
# Example for input function
input("What is your Name")
# Out:
# What is your NameAswin
# 'Aswin'

# %%
# combining the input function with print function

print("Hello " + input("What is your name?")+ "!")
# Out:
# What is your name?Aswin
# Hello Aswin!

# %% [markdown]
# ### Coding Exercise
#
# **Instructions**<br>
# Write a program that prints the number of characters in a name.<br>
#
# HINT: You might need to Google for a function that calculates the length of a string.<br>
#
# e.g.<br>
#
# https://www.google.com/search?q=how+to+get+the+length+of+a+string+in+python+stack+overflow
#
# <br>
#
# Warning. Your program should work for different inputs. e.g. any name that you input.<br>
#
# NOTE: You can access the value in the input pane using the input() function.<br>
#
# **IMPORTANT:** Don't add anything inside the input() function. e.g. use name = input() rather than: name = input("What's your name?")<br>
#
# Example Input<br>
# Jane<br>
# Example Output<br>
# 4

# %%
# solution

# assigning name variable to the input function
name = input()

# printing the number of characters of the input function using len() function
print(len(name))
# Out:
# Aswin
# 5

# %% [markdown]
# ---
# ### 4. Python Variables
#
# python variables is kind of storage space which will store the value wheather it can be user input or some values
#
# ```python
# # Variable Example
# name = input("Enter your name")
# print(name)
# ```
#
# In the above code the `name` storage space stores the input function entered by user later the variable can be called
#
# the ***variable*** can be changed

# %%
# declaring the first variable
name = "Aswin"
print(name)

# declaring the same name variable with different value
name = "Kumar"
print(name)
# Out:
# Aswin
# Kumar

# %%
# if the name variable called the last value which is stored will returned

print(name)
# Out:
# Kumar

# %%
# variable with len function

name = input("What is your name: ")
length = len(name)
print(name)
print(length)
# Out:
# What is your name: Aswin
# Aswin
# 5

# %% [markdown]
# ### Coding Exercise
#
#
# **Instructions**<br>
# This program takes two inputs. The first input is stored in a variable called a. The second input is stored in a variable called b.<br>
#
# Write a program that switches the values stored in the variables a and b.<br>
#
# **Warning:** You don't need to print anything. The print statement is already in the template code. However, your program should work for different inputs. e.g. any value of a and b.<br>
#
# Example Input 1<br>
# 29<br>
# 41<br>
# Example Output 1<br>
# a: 41<br>
# b: 29<br>
# Example Input 2<br>
# Hello<br>
# World<br>
# Example Output 2<br>
# a: World<br>
# b: Hello<br>
#
# ```python
# # There are two variables, a and b from input
# a = input()
# b = input()
# # 🚨 Don't change the code above ☝️
# ####################################
# # Write your code below this line 👇
#
#
#
#
# # Write your code above this line ☝️
# print("a: " + a)
# print("b: " + b)
# ```

# %%
# solution 1:
# There are two variables, a and b from input
a = input()
b = input()
# 🚨 Don't change the code above ☝️
####################################
# Write your code below this line 👇
c = a
a = b
b = c



# Write your code above this line ☝️
print("a: " + a)
print("b: " + b)
# Out:
# 1
# 2
# a: 2
# b: 1

# %%
# solution 2:
# There are two variables, a and b from input
a = input()
b = input()
# 🚨 Don't change the code above ☝️
####################################
# Write your code below this line 👇
a,b = b,a



# Write your code above this line ☝️
print("a: " + a)
print("b: " + b)
# Out:
# 1
# 2
# a: 2
# b: 1

# %% [markdown]
# ---
# ### 5. Variable Naming
#
# #### Rules
#
# > * Make the code (variable) readble
# > * space is not allowed to seperate two worde use `_` eg. `user_name = 'X'`
# > * The vairable name should not starts with numbers but it can be at the end or middile eg. `user1 = 'X'` is allowed `1user = 'X'` is not allowed it will throw `syntax error`
# > * Do not use inbuilt function as the variable name like `input = input()` the code will run but as the best practice avoid using the inbuilt function name as the variable

# %% [markdown]
# ### Quiz
#
# Question 1:<br>
# Which line of Python code is valid? <br>
#
# * `var a = 12`
# * `a = 12`
# * `a : 12`
# * `12 = a`
#
# <br><br>
# Answer:<br>
# `a = 12`

# %% [markdown]
# Question 2:<br>
# Which is the best variable name for Player 1's username? <br>
#
# * `p1 user name = "jackbaur"`
# * `1_player_username = "jackbaur"`
# * `player1_username = "jackbaur"`
# * `p1u = "jackbaur"`
#
# <br><br>
# Answer:<br>
# `player1_username = "jackbaur`

# %% [markdown]
# Question 3:<br>
# Which block of code will produce an error? For extra points, which type of error do you think it will produce? <br>
#
# * ```python
# time_until_midnight = "5"
# print("There are " + time_until_Midnight + " hours until midnight")
# ```
# *  ```python
# num_hours = "5"
# print("There are " + num_hours + " hours until midnight")
# ```
# *   ```python
# time_until_midnight = "5"
# print("There are " +time_until_midnight+ " hours until midnight")
# ```
#
# <br><br>
# Answer:<br>
#  ```python
# time_until_midnight = "5"
# print("There are " + time_until_Midnight + " hours until midnight")
# ```
# Reason:<br>
# Misspelt for the variable `time_until_Midnight` capital 'M' in Midnight

# %% [markdown]
# ---
#
# ## Band Name Generator
#
# ```python
# #1. Create a greeting for your program.
#
# #2. Ask the user for the city that they grew up in.
#
# #3. Ask the user for the name of a pet.
#
# #4. Combine the name of their city and pet and show them their band name.
#
# #5. Make sure the input cursor shows on a new line:
#
# # Solution: https://replit.com/@appbrewery/band-name-generator-end
# ```

# %%
#1. Create a greeting for your program.
print("Welcome to the Band Name Generator\n")

#2. Ask the user for the city that they grew up in.
city_name = input("What's name of the city you grew up in?\n")

#3. Ask the user for the name of a pet.
pet_name = input("What's your pet's name\n")

#4. Combine the name of their city and pet and show them their band name.
band_name = city_name + " " + pet_name

#5. Make sure the input cursor shows on a new line:
print("Your band name could be" + " " + band_name)
# Solution: https://replit.com/@appbrewery/band-name-generator-end
# Out:
# Welcome to the Band Name Generator
#
# What's name of the city you grew up in?
# Bangalore
# What's your pet's name
# Pappu
# Your band name could be Bangalore Pappu

# %% [markdown]
# ---
# ## <center>Done for the Day 1!!!</center>
