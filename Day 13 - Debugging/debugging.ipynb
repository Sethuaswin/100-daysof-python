# %% [markdown]
# # <center> Debugging</center>

# %% [markdown]
# ## Overview
# * Debugging
#
# In this session we will look in to,
# How to find the bug and get rid of it

# %% [markdown]
# ### Steps
#
# 1. Describe the problem
# 2. Reproducing the bug
# 3. Try to play like a computer
# 4. Fixing the errors
# 5. Print statement will help you to identify the bug which won't throw any error
# 6. Use a debugger like - [python tutor](https://pythontutor.com/python-compiler.html#mode=edit)
#
# Additional Tips
#
# 7. Take a break
# 8. Ask a Friend
# 9. Run Often
# 10. Ask StackOverflow

# %%
############DEBUGGING#####################

# # Describe Problem
# def my_function():
#     for i in range(1, 21): # here range function not including 20
#         if i == 20:
#             print("You got it")
# my_function()

# # Reproduce the Bug
# # In the below bug sometimes the code will through "IndexError: list index out of range" Error but not always
# from random import randint
# dice_imgs = ["❶", "❷", "❸", "❹", "❺", "❻"]
# # dice_num = randint(1, 6) # Here randint will produce including starting and ending since 6 is out of index it throws as error
# dice_num = randint(0, 5)
# # dice_num = 6
# print(dice_imgs[dice_num])

# # Play Computer
# year = int(input("What's your year of birth?"))
# # if year > 1980 and year < 1994: # here there is no condition for 1994
# if year > 1980 and year < 1994:
#   print("You are a millenial.")
# elif year >= 1994:
#   print("You are a Gen Z.")

# # Fix the Errors
# # age = input("How old are you?") # input function always be as string
# age = int(input("How old are you?"))
# if age > 18:
#     # print("You can drive at age {age}.") # Here there is no f-strings
#     print(f"You can drive at age {age}.")

# #Print is Your Friend
# pages = 0
# word_per_page = 0
# pages = int(input("Number of pages: "))
# # word_per_page == int(input("Number of words per page: ")) # Here the variable is checking whether the sattement is true
# word_per_page = int(input("Number of words per page: "))
# total_words = pages * word_per_page
# print("Number of Pages = ",pages)
# print("Word per pages = ", word_per_page)
# print(total_words)

# #Use a Debugger
# # %debug
# def mutate(a_list):
#     b_list = []
#     for item in a_list:
#         new_item = item * 2
#     # b_list.append(new_item) # The issue is the intendation of this append it will append only the last item from the list
#         b_list.append(new_item)
#     print(b_list)

# mutate([1,2,3,5,8,13])
# Out:
# [2, 4, 6, 10, 16, 26]

# %% [markdown]
# ### Coding Exercise
#
#
# **Instructions**
# * Read this the code in main.py
# * Spot the problems 🐞.
# * Modify the code to fix the program.
# Fix the code so that it works and passes the tests when you submit.
#
# Hint<br>
# Review the previous lesson and go through the 10 steps to tackle these debugging problems.

# %%
number = int(input()) # Which number do you want to check?

######## BUG ################
# if number % 2 = 0:
############################
if number % 2 == 0:
  print("This is an even number.")
else:
  print("This is an odd number.")
# Out:
# 45
# This is an odd number.

# %% [markdown]
# ### Coding Exercise
#
#
# **Instructions**
# * Read this the code in main.py
# * Spot the problems 🐞.
# * Modify the code to fix the program.
# * No shortcuts - don't copy-paste to replace the code entirely with a working solution.
#
# Fix the code so that it works and when you hit submit it should pass all the tests.

# %%
# Which year do you want to check?

####### Bug ############
# year = input()
########################
year = int(input())
if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("Leap year.")
    else:
      print("Not leap year.")
  else:
    print("Leap year.")
else:
  print("Not leap year.")
# Out:
# 2020
# Leap year.

# %% [markdown]
# **Instructions**
# * Read this the code in main.py
# * Spot the problems 🐞.
# * Modify the code to fix the program.
# * No shortcuts - don't copy-paste to replace the code entirely with a working solution.
# The code needs to print the solution to the FizzBuzz game.
#
# * Your program should print each number from 1 to x where x is the input number.
#
# * However when the number is divisible by 3 then instead of printing the number it should print "Fizz".
#
# * When the number is divisible by 5, then instead of printing the number it should print "Buzz".
#
# * And if the number is divisible by both 3 and 5 e.g. 15 then instead of the number it should print "FizzBuzz".
#
# Hint<br>
# There is more than one fix required.

# %%
target = int(input())
for number in range(1, target + 1):
    ########### BUG ##################
    # if number % 3 == 0 or number % 5 == 0:
    ###################################
    if number % 3 == 0 and number % 5 == 0:
        print("FizzBuzz")
    elif number % 3 == 0: # Bug if is there instead of elif
        print("Fizz")
    elif number % 5 == 0: # Bug if is there instead of elif
        print("Buzz")
    else:
        print(number) # [] should be removed
# Out:
# 15
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz

# %% [markdown]
# ----
